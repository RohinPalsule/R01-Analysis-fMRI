# %%
# %load_ext autoreload
# %autoreload 2
from glm_tasks import GWF_StudyGLM

glm = GWF_StudyGLM()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# TEST

# %%
fit_glm = glm.fit_glm()
# Out:
# Computing run 1 out of 1 runs (go take a coffee, a big one)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/first_level/experimental_paradigm.py:167: UserWarning: The following unexpected columns in events data will be ignored: accuracy, node_l, node_r, block, trial
#   warnings.warn(
#
# Computation of 1 runs done in 25.531412839889526 seconds.

# %%
from nilearn.plotting import plot_design_matrix
plot_design_matrix(fit_glm.design_matrices_[0])
# Out:
# <Axes: label='conditions', ylabel='scan number'>

# %%
design_matrix = fit_glm.design_matrices_[0] # Just a dummy matrix for regressors
n_regressors = design_matrix.shape[1]
n_regressors
import numpy as np
contrasts = np.zeros(n_regressors)
contrasts[0] = -1
contrasts[1] = 0
contrasts[3] = 0
contrasts[4] = 1

# %%
glm.plot_contrast_map(glm=fit_glm,name="weighted_order",contrasts=[-1,-0.5,-0.5,1])
# Out:
# results/GLM_Study/contrast_maps

# %%
fit_glm
# Out:
# FirstLevelModel(high_pass=0.0078125, hrf_model='spm', t_r=2, verbose=1)
